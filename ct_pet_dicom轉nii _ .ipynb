# %%
import pandas as pd
import os
import shutil
import dicom2nift

# %%
df = pd.read_excel(r"D:/使用者/Downloads/01.xlsx")#改成你的excel檔位置
ID_NOT_LIVING_OVER_THREE_YEARS = []
ID_LIVING_OVER_THREE_YEARS = []
for i in range(193):
    if df.at[i,"ny3"]==0:
        ID_NOT_LIVING_OVER_THREE_YEARS.append(df.at[i,"ID"])   
    if df.at[i,"ny3"]==1:
        ID_LIVING_OVER_THREE_YEARS.append(df.at[i,"ID"])

# %%
path_dir = r"E:/整理/0"
name_dir = os.listdir(path_dir)
save_path = r"E:/ct_pet_nii/live_not_more_three_year"
for i in name_dir:
    ct_path=os.path.join(path_dir,i)
    nii_ct_path_dir=os.path.join(save_path,i)
    nii_ct_path=os.mkdir(nii_ct_path_dir)#應該不用這行，因為這是再創一個資料夾
    #dicom2nifti.convert_directory(ct_path, nii_ct_path)

# %%
path_dir = r"E:/整理/0"
name_dir = os.listdir(path_dir)
save_path = r"E:/ct_pet_nii/live_not_more_three_year"
for i in name_dir:
    ct_path=os.path.join(path_dir,i)
    nii_ct_path=os.path.join(save_path,i)
    dicom2nifti.convert_directory(ct_path, nii_ct_path)

# %%
path_dir = r"E:/整理/1"
name_dir = os.listdir(path_dir)
save_path = r"E:/ct_pet_nii/live_more_three_year"
for i in name_dir:
    ct_path=os.path.join(path_dir,i)
    nii_ct_path_dir=os.path.join(save_path,i)
    nii_ct_path=os.mkdir(nii_ct_path_dir)

# %%
path_dir = r"E:/整理/1"
name_dir = os.listdir(path_dir)
save_path = r"E:/ct_pet_nii/live_more_three_year"
for i in name_dir:
    ct_path=os.path.join(path_dir,i)
    nii_ct_path=os.path.join(save_path,i)
    dicom2nifti.convert_directory(ct_path, nii_ct_path)
